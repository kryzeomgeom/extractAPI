# %%
import os
import json
import requests
import pandas as pd

# %%
url = "https://api.api-ninjas.com/v1/planets?name=Neptune"
headers = {
     "X-API-Key": "6P3GClsDs8DuYT2SOfBJXl2TAK1PsDd10BshNVBF"
}

# %%
response = requests.get(url=url, headers=headers)

# %%
print(response.json())
# Out:
# [{'name': 'Neptune', 'mass': 0.0537, 'radius': 0.346, 'period': 59800.0, 'semi_major_axis': 30.07, 'temperature': 72.0, 'distance_light_year': 0.000478, 'host_star_mass': 1.0, 'host_star_temperature': 6000.0}]
